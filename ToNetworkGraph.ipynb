# %% [markdown]
# ## Wrangling the raw data in prep for Network Graph ##
# In the Network Graph, want to show which Parent Entity has the most influence and in which platform. Only 1 value column is needed, so we need to merge all Subscriber Number into 1 column and to have another column to specify which platform those figures were from.

# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)

# %%
df1 = pd.read_excel("CANIS_PRC_state_media_on_social_media_platforms-2023-11-03.xlsx")
# drop Chinese columns
df1.drop(columns=["Name (Chinese)","Entity owner (Chinese)","Parent entity (Chinese)"], inplace=True)

# %%
columns_to_wrangle = ['X (Twitter) Follower #',
                      'Facebook Follower #',
                      'Instagram Follower #',
                      'Threads Follower #',
                      'YouTube Subscriber #',
                      'TikTok Subscriber #']

# %%
df1.head()
# Out:
#                       Name (English) Region of Focus Language  \
# 0           Yang Xinmeng (Abby Yang)     Anglosphere  English
# 1               CGTN Culture Express     Anglosphere  English
# 2     All-China Students' Federation           China  Chinese
# 3  Chen Zhong (Dechinghutay / Ghoti)     Afghanistan   Pashto
# 4                         Yang Sheng     Anglosphere  English
#
#            Entity owner (English)  \
# 0         China Media Group (CMG)
# 1         China Media Group (CMG)
# 2  All-China Students' Federation
# 3         China Media Group (CMG)
# 4            People's Daily Press
#
#                             Parent entity (English) X (Twitter) handle  \
# 0                      Central Publicity Department       _bubblyabby_
# 1                      Central Publicity Department    _cultureexpress
# 2   Central Committee of the Communist Youth League           ACSF1919
# 3                      Central Publicity Department        afghanchina
# 4  Central Committee of the Chinese Communist Party       AlexYsalex17
#
#                        X (Twitter) URL  X (Twitter) Follower #  \
# 0     https://twitter.com/_bubblyabby_                  1678.0
# 1  https://twitter.com/_cultureexpress                  2488.0
# 2         https://twitter.com/ACSF1919                  5136.0
# 3      https://twitter.com/afghanchina                  1800.0
# 4     https://twitter.com/AlexYsalex17                  2821.0
#
#              Facebook page                                      Facebook URL  \
# 0  itsAbby-103043374799622  https://www.facebook.com/itsAbby-103043374799622
# 1                      NaN                                               NaN
# 2                      NaN                                               NaN
# 3             dechinghutay            https://www.facebook.com/dechinghutay/
# 4                      NaN                                               NaN
#
#    Facebook Follower #   Instragram page  \
# 0            1387432.0      _bubblyabby_
# 1                  NaN  _cultureexpress/
# 2                  NaN               NaN
# 3            1600000.0               NaN
# 4                  NaN               NaN
#
#                                 Instagram URL  Instagram Follower #  \
# 0     https://www.instagram.com/_bubblyabby_/                9507.0
# 1  https://www.instagram.com/_cultureexpress/                 635.0
# 2                                         NaN                   NaN
# 3                                         NaN                   NaN
# 4                                         NaN                   NaN
#
#   Threads account                            Threads URL  Threads Follower #  \
# 0    _bubblyabby_  https://www.threads.net/@_bubblyabby_               197.0
# 1             NaN                                    NaN                 NaN
# 2             NaN                                    NaN                 NaN
# 3             NaN                                    NaN                 NaN
# 4             NaN                                    NaN                 NaN
#
#   YouTube account                                        YouTube URL  \
# 0         itsAbby                    https://www.youtube.com/itsAbby
# 1             NaN                                                NaN
# 2             NaN                                                NaN
# 3    dechinghutay  https://www.youtube.com/channel/UCXl9X2fi65wKf...
# 4             NaN                                                NaN
#
#    YouTube Subscriber # TikTok account                            TikTok URL  \
# 0                4680.0   _bubblyabby_  https://www.tiktok.com/@_bubblyabby_
# 1                   NaN            NaN                                   NaN
# 2                   NaN            NaN                                   NaN
# 3                 695.0   dechinghutay  https://www.tiktok.com/@dechinghutay
# 4                   NaN            NaN                                   NaN
#
#    TikTok Subscriber #
# 0                660.0
# 1                  NaN
# 2                  NaN
# 3             326100.0
# 4                  NaN

# %% [markdown]
# ### Drop account name or handle and links for each platform. ###
# Only wanted the subscriber numbers for network graph

# %%
columns_to_drop = [5,6,8,9,11,12,14,15,17,18,20,21]
df1.drop(df1.columns[columns_to_drop], axis=1, inplace=True)
df1.head()
# Out:
#                       Name (English) Region of Focus Language  \
# 0           Yang Xinmeng (Abby Yang)     Anglosphere  English
# 1               CGTN Culture Express     Anglosphere  English
# 2     All-China Students' Federation           China  Chinese
# 3  Chen Zhong (Dechinghutay / Ghoti)     Afghanistan   Pashto
# 4                         Yang Sheng     Anglosphere  English
#
#            Entity owner (English)  \
# 0         China Media Group (CMG)
# 1         China Media Group (CMG)
# 2  All-China Students' Federation
# 3         China Media Group (CMG)
# 4            People's Daily Press
#
#                             Parent entity (English)  X (Twitter) Follower #  \
# 0                      Central Publicity Department                  1678.0
# 1                      Central Publicity Department                  2488.0
# 2   Central Committee of the Communist Youth League                  5136.0
# 3                      Central Publicity Department                  1800.0
# 4  Central Committee of the Chinese Communist Party                  2821.0
#
#    Facebook Follower #  Instagram Follower #  Threads Follower #  \
# 0            1387432.0                9507.0               197.0
# 1                  NaN                 635.0                 NaN
# 2                  NaN                   NaN                 NaN
# 3            1600000.0                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
#
#    YouTube Subscriber #  TikTok Subscriber #
# 0                4680.0                660.0
# 1                   NaN                  NaN
# 2                   NaN                  NaN
# 3                 695.0             326100.0
# 4                   NaN                  NaN

# %% [markdown]
# ### Create two new columns: Platform and Followers ###
# - Rearrange table and sort into rows with most platforms (computing a simple statistics along the way)
# - Remove any rows that are null or without any followers on any of the platforms
# - Wrangle and Melt the Follower or Subscriber columns into one column

# %%
columns_to_count = ['X (Twitter) Follower #',
                    'Facebook Follower #',
                    'Instagram Follower #',
                    'Threads Follower #',
                    'YouTube Subscriber #',
                    'TikTok Subscriber #']
df1['NumAccount'] = df1[columns_to_count].count(axis=1)
df1 = df1.sort_values(by='NumAccount', ascending=False).reset_index(drop=True)
#df_sorted.drop(columns='non_null_count', inplace=True)
df1 = df1[df1['NumAccount'] > 0]
NumAccount_Count = []
for i in range(6,0,-1):
    NumAccount_Count.append(len(df1[df1["NumAccount"] == i]))
NumAccount_Count
# Out:
# [10, 24, 42, 82, 157, 442]

# %%
len(df1)
# Out:
# 757

# %%
list(df1.columns)
# Out:
# ['Name (English)',
#  'Region of Focus',
#  'Language',
#  'Entity owner (English)',
#  'Parent entity (English)',
#  'X (Twitter) Follower #',
#  'Facebook Follower #',
#  'Instagram Follower #',
#  'Threads Follower #',
#  'YouTube Subscriber #',
#  'TikTok Subscriber #',
#  'NumAccount']

# %%
df1.head(10)
# Out:
#                Name (English) Region of Focus Language  \
# 0    Yang Xinmeng (Abby Yang)     Anglosphere  English
# 1                 China Daily     Anglosphere  English
# 2             Where Zhengzhou     Anglosphere  English
# 3              People's Daily           China  Chinese
# 4               Miao Xiaojuan     Anglosphere  English
# 5                 Li Jingjing     Anglosphere  English
# 6  Zang Shijie (Jessica Zang)     Anglosphere  English
# 7                      iPanda     Anglosphere  English
# 8                  iChongqing       Chongqing  English
# 9          Li Yimei (Vica Li)     Anglosphere  English
#
#                          Entity owner (English)  \
# 0                       China Media Group (CMG)
# 1                             China Daily Press
# 2                         Zhengzhou Media Group
# 3                          People's Daily Press
# 4                            Xinhua News Agency
# 5                       China Media Group (CMG)
# 6                       China Media Group (CMG)
# 7                       China Media Group (CMG)
# 8  Chongqing International Communication Center
# 9                       China Media Group (CMG)
#
#                             Parent entity (English)  X (Twitter) Follower #  \
# 0                      Central Publicity Department                  1678.0
# 1                      Central Publicity Department               4100000.0
# 2               Zhengzhou Municipal Party Committee                 14900.0
# 3  Central Committee of the Chinese Communist Party               6600000.0
# 4                                     State Council                  6577.0
# 5                      Central Publicity Department                 30000.0
# 6                      Central Publicity Department                  3083.0
# 7                      Central Publicity Department                159500.0
# 8                     Chongqing Municipal Committee                189300.0
# 9                      Central Publicity Department                  1707.0
#
#    Facebook Follower #  Instagram Follower #  Threads Follower #  \
# 0            1387432.0                9507.0               197.0
# 1          104613175.0             1300000.0             40200.0
# 2              10000.0               26400.0                40.0
# 3           85867335.0             1300000.0             28200.0
# 4            1800000.0                2445.0                85.0
# 5            2900000.0               23900.0               950.0
# 6            1200000.0                8413.0               173.0
# 7           24000000.0             2400000.0            121000.0
# 8            7000000.0               11500.0               380.0
# 9            1300000.0              115000.0              6669.0
#
#    YouTube Subscriber #  TikTok Subscriber #  NumAccount
# 0                4680.0                660.0           6
# 1              337000.0            1300000.0           6
# 2                1470.0               5961.0           6
# 3              410000.0            2600000.0           6
# 4                1030.0                  3.0           6
# 5               58300.0              17200.0           6
# 6                 967.0              16800.0           6
# 7             2180000.0            2500000.0           6
# 8               26900.0                632.0           6
# 9                7290.0               8885.0           6

# %%
columns_to_keep = ['Name (English)', 'Region of Focus', 'Language', 
                   'Entity owner (English)','Parent entity (English)',]
df1_melted = df1.melt(id_vars=columns_to_keep, value_vars=columns_to_count,
                     var_name='Platform', value_name='Followers')

# %%
df1_melted[df1_melted["Platform"]=="Instagram Follower #"].head(20)
# Out:
#                                        Name (English)  Region of Focus  \
#
#       Followers
# 1514     9507.0
# 1515  1300000.0
# 1516    26400.0
# 1517  1300000.0
# 1518     2445.0
# 1519    23900.0
# 1520     8413.0
# 1521  2400000.0
# 1522    11500.0
# 1523   115000.0
# 1524     6833.0
# 1525    21300.0
# 1526   248000.0
# 1527    69500.0
# 1528  2300000.0
# 1529    41100.0
# 1530   298000.0
# 1531     2190.0
# 1532  1500000.0
# 1533       16.0

# %%
# Get rid of the " Follower #" and " Subscriber #" in Platform column
df1_melted['Platform'] = df1_melted['Platform'].replace(" Follower #", "", regex=True)
df1_melted['Platform'] = df1_melted['Platform'].replace(" Subscriber #", "", regex=True)

# %%
df1_melted[df1_melted["Platform"].str.contains("Twitter")].head(1)
# Out:
#              Name (English) Region of Focus Language   Entity owner (English)  \
# 0  Yang Xinmeng (Abby Yang)     Anglosphere  English  China Media Group (CMG)
#
#         Parent entity (English)     Platform  Followers
# 0  Central Publicity Department  X (Twitter)     1678.0

# %%
df1_melted[df1_melted["Platform"].str.contains("Facebook")].head(1)
# Out:
#                Name (English) Region of Focus Language  \
# 757  Yang Xinmeng (Abby Yang)     Anglosphere  English
#
#       Entity owner (English)       Parent entity (English)  Platform  \
# 757  China Media Group (CMG)  Central Publicity Department  Facebook
#
#      Followers
# 757  1387432.0

# %%
df1_melted[df1_melted["Platform"].str.contains("Instagram")].head(1)
# Out:
#                 Name (English) Region of Focus Language  \
# 1514  Yang Xinmeng (Abby Yang)     Anglosphere  English
#
#        Entity owner (English)       Parent entity (English)   Platform  \
# 1514  China Media Group (CMG)  Central Publicity Department  Instagram
#
#       Followers
# 1514     9507.0

# %%
df1_melted[df1_melted["Platform"].str.contains("Threads")].head(1)
# Out:
#                 Name (English) Region of Focus Language  \
# 2271  Yang Xinmeng (Abby Yang)     Anglosphere  English
#
#        Entity owner (English)       Parent entity (English) Platform  \
# 2271  China Media Group (CMG)  Central Publicity Department  Threads
#
#       Followers
# 2271      197.0

# %%
df1_melted[df1_melted["Platform"].str.contains("YouTube")].head(1)
# Out:
#                 Name (English) Region of Focus Language  \
# 3028  Yang Xinmeng (Abby Yang)     Anglosphere  English
#
#        Entity owner (English)       Parent entity (English) Platform  \
# 3028  China Media Group (CMG)  Central Publicity Department  YouTube
#
#       Followers
# 3028     4680.0

# %%
df1_melted[df1_melted["Platform"].str.contains("TikTok")].head(1)
# Out:
#                 Name (English) Region of Focus Language  \
# 3785  Yang Xinmeng (Abby Yang)     Anglosphere  English
#
#        Entity owner (English)       Parent entity (English) Platform  \
# 3785  China Media Group (CMG)  Central Publicity Department   TikTok
#
#       Followers
# 3785      660.0

# %%
# drop null in Followers columns before exporting
df1_filtered = df1_melted.dropna(subset=["Followers"])

# %%
df1_filtered.to_csv("dataset_for_NetworkGraph.csv", index=False)
